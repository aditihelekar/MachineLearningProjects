# %%
# Import the pandas package, then use the "read_csv" function to read
# the labeled training data
import pandas as pd   
import os
from bs4 import BeautifulSoup   
import re
from nltk.corpus import stopwords # Import the stop word list
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score

def review_to_words( raw_review ):
    # Function to convert a raw review to a string of words
    # The input is a single string (a raw movie review), and 
    # the output is a single string (a preprocessed movie review)
    #
    # 1. Remove HTML
    example1 = BeautifulSoup(raw_review)
    review_text = example1.get_text()
    #
    # 2. Remove non-letters        
    letters_only = re.sub("[^a-zA-Z]", " ", review_text) 
    #
    # 3. Convert to lower case, split into individual words
    words = letters_only.lower().split()                             
    #
    # 4. In Python, searching a set is much faster than searching
    #   a list, so convert the stop words to a set
    stops = set(stopwords.words("english"))                  
    # 
    # 5. Remove stop words
    meaningful_words = [w for w in words if not w in stops]   
    #print(meaningful_words)
    #
    # 6. Join the words back into one string separated by space, 
    # and return the result.
    return( " ".join( meaningful_words ))   

def main():

    #os.chdir("E:\ComputerScience\Sem2\ML\ITCS6156_SLProject\AmazonReviews")    
    train = pd.read_csv("amazon_baby_train.csv")
    print(train["review"][167])
    print(train.shape)
    print("Size::" , train["review"].size)
    train = train.dropna(subset=['review'])
    print("Size::" , train["review"].size, train["rating"].size)
    clean_review = review_to_words( train["review"][0] )
    print( clean_review)
    # Get the number of reviews based on the dataframe column size
    num_reviews = train["review"].size

    # Initialize an empty list to hold the clean reviews
    clean_train_reviews = []

    # Loop over each review; create an index i that goes from 0 to the length
    # of the movie review list 
    for i in range(0, num_reviews):
        # If the index is evenly divisible by 1000, print a message
        #print(i)
        if( (i+1)%1000 == 0 ):
            print( "Review %d of %d\n" % ( i+1, num_reviews ))
        try:
            clean_train_reviews.append( review_to_words( train["review"][i] ))
        except KeyError:
            clean_train_reviews.append(" 0 ")
            print("Value not found", i)

        
    print( "Creating the bag of words...\n")


    # Initialize the "CountVectorizer" object, which is scikit-learn's
    # bag of words tool.  
    vectorizer = CountVectorizer(analyzer = "word",   \
                                 tokenizer = None,    \
                                 preprocessor = None, \
                                 stop_words = None,   \
                                 max_features = 5000) 
    
    # fit_transform() does two functions: First, it fits the model
    # and learns the vocabulary; second, it transforms our training data
    # into feature vectors. The input to fit_transform should be a list of 
    # strings.
    train_data_features = vectorizer.fit_transform(clean_train_reviews)
    

    print( train_data_features.shape)

    vocab = vectorizer.get_feature_names()
    print( vocab)
    import numpy as np

    dist = np.sum(train_data_features, axis=0)

    for tag, count in zip(vocab, dist):
        print( count, tag)
        
    print( "Training the model...")
    
    classifier = MultinomialNB()
    classifier.fit(train_data_features, train["rating"])
    
    # Read the test data
    test = pd.read_csv("amazon_baby_test.csv")
    test = test.dropna(subset=['review'])
    
 
    print (test.shape)
    

    num_reviews = len(test["review"])A
    clean_test_reviews = [] 
    
    print( "Cleaning and parsing the test set movie reviews...\n")
    for i in range(0,num_reviews):
        if( (i+1) % 1000 == 0 ):
            print ("Review %d of %d\n" % (i+1, num_reviews))
        try:
            clean_review = review_to_words( test["review"][i] )
            clean_test_reviews.append( clean_review )
        except KeyError:
            clean_test_reviews.append(" 0 ")
            print("Value not found in test", i)
    
    test_data_features = vectorizer.transform(clean_test_reviews)

    result = classifier.predict(test_data_features)
    print(result)
    ratings = test["rating"]
    print("Accuracy:")
    print(accuracy_score(ratings, result))
   
main()
# Out:
#   File "<ipython-input-1-1fc79cb9dc01>", line 109
#     num_reviews = len(test["review"])A
#                                      ^
# SyntaxError: invalid syntax

# %%
# Import the pandas package, then use the "read_csv" function to read
# the labeled training data
import pandas as pd   
import os
from bs4 import BeautifulSoup   
import re
from nltk.corpus import stopwords # Import the stop word list
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score

def review_to_words( raw_review ):
    # Function to convert a raw review to a string of words
    # The input is a single string (a raw movie review), and 
    # the output is a single string (a preprocessed movie review)
    #
    # 1. Remove HTML
    example1 = BeautifulSoup(raw_review)
    review_text = example1.get_text()
    #
    # 2. Remove non-letters        
    letters_only = re.sub("[^a-zA-Z]", " ", review_text) 
    #
    # 3. Convert to lower case, split into individual words
    words = letters_only.lower().split()                             
    #
    # 4. In Python, searching a set is much faster than searching
    #   a list, so convert the stop words to a set
    stops = set(stopwords.words("english"))                  
    # 
    # 5. Remove stop words
    meaningful_words = [w for w in words if not w in stops]   
    #print(meaningful_words)
    #
    # 6. Join the words back into one string separated by space, 
    # and return the result.
    return( " ".join( meaningful_words ))   

def main():

    #os.chdir("E:\ComputerScience\Sem2\ML\ITCS6156_SLProject\AmazonReviews")    
    train = pd.read_csv("amazon_baby_train.csv")
    print(train["review"][167])
    print(train.shape)
    print("Size::" , train["review"].size)
    train = train.dropna(subset=['review'])
    print("Size::" , train["review"].size, train["rating"].size)
    clean_review = review_to_words( train["review"][0] )
    print( clean_review)
    # Get the number of reviews based on the dataframe column size
    num_reviews = train["review"].size

    # Initialize an empty list to hold the clean reviews
    clean_train_reviews = []

    # Loop over each review; create an index i that goes from 0 to the length
    # of the movie review list 
    for i in range(0, num_reviews):
        # If the index is evenly divisible by 1000, print a message
        #print(i)
        if( (i+1)%1000 == 0 ):
            print( "Review %d of %d\n" % ( i+1, num_reviews ))
        try:
            clean_train_reviews.append( review_to_words( train["review"][i] ))
        except KeyError:
            clean_train_reviews.append(" 0 ")
            print("Value not found", i)

        
    print( "Creating the bag of words...\n")


    # Initialize the "CountVectorizer" object, which is scikit-learn's
    # bag of words tool.  
    vectorizer = CountVectorizer(analyzer = "word",   \
                                 tokenizer = None,    \
                                 preprocessor = None, \
                                 stop_words = None,   \
                                 max_features = 5000) 
    
    # fit_transform() does two functions: First, it fits the model
    # and learns the vocabulary; second, it transforms our training data
    # into feature vectors. The input to fit_transform should be a list of 
    # strings.
    train_data_features = vectorizer.fit_transform(clean_train_reviews)
    

    print( train_data_features.shape)

    vocab = vectorizer.get_feature_names()
    print( vocab)
    import numpy as np

    dist = np.sum(train_data_features, axis=0)

    for tag, count in zip(vocab, dist):
        print( count, tag)
        
    print( "Training the model...")
    
    classifier = MultinomialNB()
    classifier.fit(train_data_features, train["rating"])
    
    # Read the test data
    test = pd.read_csv("amazon_baby_test.csv")
    test = test.dropna(subset=['review'])
    
 
    print (test.shape)
    

    num_reviews = len(test["review"])
    clean_test_reviews = [] 
    
    print( "Cleaning and parsing the test set movie reviews...\n")
    for i in range(0,num_reviews):
        if( (i+1) % 1000 == 0 ):
            print ("Review %d of %d\n" % (i+1, num_reviews))
        try:
            clean_review = review_to_words( test["review"][i] )
            clean_test_reviews.append( clean_review )
        except KeyError:
            clean_test_reviews.append(" 0 ")
            print("Value not found in test", i)
    
    test_data_features = vectorizer.transform(clean_test_reviews)

    result = classifier.predict(test_data_features)
    print(result)
    ratings = test["rating"]
    print("Accuracy:")
    print(accuracy_score(ratings, result))
   
main()
# Out:
# nan
# (146824, 3)
# Size:: 146824
# Size:: 146182 146182
# bought daughter expecting first baby said friends said one item absolutely must easy put waiting baby
# C:\Users\Aditi\Anaconda3\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 184 of the file C:\Users\Aditi\Anaconda3\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))
# Value not found 167
# Value not found 313
# Review 1000 of 146182
#
# Value not found 1196
# Value not found 1431
# Value not found 1815
# Value not found 1986
# Review 2000 of 146182
#
# Value not found 2380
# Value not found 2551
# Review 3000 of 146182
#
# Value not found 3023
# Value not found 3547
# Value not found 3563
# Value not found 3850
# Value not found 3917
# Review 4000 of 146182
#
# Value not found 4415
# Review 5000 of 146182
#
# Value not found 5502
# Value not found 5866
# Review 6000 of 146182
#
# Value not found 6440
# Value not found 6464
# Value not found 6471
# Value not found 6547
# Value not found 6811
# Review 7000 of 146182
# ['aa', 'ability', 'able', 'absolute', 'absolutely', 'absorb', 'absorbant', 'absorbency', 'absorbent', 'absorbing', 'absorbs', 'abuse', 'ac', 'accept', 'acceptable', 'access', 'accessible', 'accessories', 'accessory', 'accident', 'accidentally', 'accidents', 'accommodate', 'accomodate', 'according', 'account', 'accurate', 'acid', 'across', 'act', 'action', 'activate', 'activated', 'activation', 'active', 'activities', 'activity', 'acts', 'actual', 'actually', 'ad', 'adapter', 'adapters', 'adaptor', 'add', 'added', 'adding', 'addition', 'additional', 'additionally', 'address', 'adds', 'aden', 'adequate', 'adhere', 'adhesive', 'adjust', 'adjustable', 'adjusted', 'adjuster', 'adjusting', 'adjustment', 'adjustments', 'adjusts', 'admit', 'adorable', 'adore', 'adores', 'adult', 'adults', 'advance', 'advanced', 'advantage', 'advent', 'advertised', 'advertising', 'advice', 'advise', 'advised', 'advocate', 'affect', 'afford', 'affordable', 'afraid', 'afternoon', 'afterwards', 'age', 'ages', 'agile', 'ago', 'agree', 'agreed', 'ahead', 'aid', 'aio', 'air', 'airline', 'airplane', 'airport', 'airports', 'alarm', 'alarms', 'album', 'alcohol', 'alert', 'align', 'aligned', 'allow', 'allowed', 'allowing', 'allows', 'almost', 'alone', 'along', 'alot', 'alphabet', 'already', 'alright', 'also', 'alternate', 'alternative', 'alternatives', 'although', 'altogether', 'alva', 'always', 'amazed', 'amazing', 'amazingly', 'amazon', 'amber', 'ameda', 'american', 'among', 'amount', 'amounts', 'ample', 'anais', 'anchor', 'anchors', 'angel', 'angle', 'angled', 'angles', 'angry', 'animal', 'animals', 'annoyance', 'annoyed', 'annoying', 'another', 'answer', 'antenna', 'anti', 'anticipate', 'anticipated', 'anybody', 'anyhow', 'anymore', 'anyone', 'anything', 'anytime', 'anyway', 'anyways', 'anywhere', 'apart', 'apartment', 'app', 'apparent', 'apparently', 'appeal', 'appealing', 'appear', 'appearance', 'appeared', 'appears', 'apple', 'applesauce', 'application', 'applied', 'apply', 'applying', 'appreciate', 'appreciated', 'appropriate', 'approved', 'approx', 'approximately', 'april', 'aquarium', 'arch', 'area', 'areas', 'arm', 'armrests', 'arms', 'around', 'arrival', 'arrive', 'arrived', 'arrives', 'art', 'asap', 'aside', 'ask', 'asked', 'asking', 'asks', 'asleep', 'aspect', 'aspirator', 'assemble', 'assembled', 'assembling', 'assembly', 'assistance', 'assume', 'assumed', 'assuming', 'assured', 'ate', 'attach', 'attached', 'attaches', 'attaching', 'attachment', 'attachments', 'attempt', 'attempted', 'attempting', 'attempts', 'attention', 'attracted', 'attractive', 'audio', 'august', 'auto', 'automatic', 'automatically', 'avail', 'available', 'avent', 'average', 'avoid', 'awake', 'aware', 'away', 'awesome', 'awful', 'awhile', 'awkward', 'awkwardly', 'babe', 'babies', 'babiesrus', 'baby', 'babybjorn', 'babys', 'babysitter', 'back', 'background', 'backing', 'backpack', 'backs', 'backseat', 'backup', 'backward', 'backwards', 'bacteria', 'bad', 'badly', 'bag', 'baggage', 'bags', 'baking', 'balance', 'balanced', 'ball', 'balls', 'bamboo', 'banana', 'bananas', 'band', 'bands', 'bang', 'banging', 'banister', 'bank', 'baptism', 'bar', 'bare', 'barely', 'bargain', 'barn', 'barrier', 'bars', 'base', 'based', 'basement', 'bases', 'basic', 'basically', 'basis', 'basket', 'baskets', 'bassinet', 'bassinets', 'bat', 'batch', 'bath', 'bathe', 'bather', 'bathing', 'bathroom', 'bathrooms', 'baths', 'bathtime', 'bathtub', 'batteries', 'battery', 'bauer', 'bay', 'bb', 'bc', 'beach', 'beads', 'bear', 'bears', 'beat', 'beating', 'beats', 'beautiful', 'beautifully', 'bebe', 'became', 'beco', 'become', 'becomes', 'becoming', 'becuase', 'bed', 'bedding', 'bedroom', 'beds', 'bedtime', 'bee', 'beep', 'beeping', 'beeps', 'began', 'begin', 'beginning', 'begins', 'begun', 'behind', 'beige', 'believe', 'bell', 'bells', 'belly', 'belt', 'belts', 'bench', 'bend', 'bending', 'bends', 'beneath', 'benefit', 'benefits', 'bent', 'beside', 'besides', 'best', 'bet', 'better', 'beware', 'beyond', 'bf', ' ...
# [[ 101  760 9754 ...,   88  252  320]] aa
# Training the model...
# (36520, 3)
# Cleaning and parsing the test set movie reviews...
#
# Value not found in test 254
# Value not found in test 684
# Value not found in test 738
# Value not found in test 767
# Review 1000 of 36520
#
# Value not found in test 1637
# Value not found in test 1839
# Value not found in test 1882
# Review 2000 of 36520
#
# Value not found in test 2045
# Value not found in test 2071
# Value not found in test 2708
# Value not found in test 2778
# Review 3000 of 36520
#
# Review 4000 of 36520
#
# Value not found in test 4078
# Value not found in test 4272
# Value not found in test 4588
# Review 5000 of 36520
#
# Value not found in test 5336
# Value not found in test 5383
# Value not found in test 5595
# Value not found in test 5611
# Value not found in test 5932
# Value not found in test 5974
# Review 6000 of 36520
#
# Value not found in test 6008
# Value not found in test 6068
# Value not found in test 6287
# Value not found in test 6312
# Value not found in test 6618
# Value not found in test 6707
# Review 7000 of 36520
#
# Value not found in test 7141
# Value not found in test 7315
# Value not found in test 7550
# Value not found in test 7959
# Value not found in test 7992
# Review 8000 of 36520
#
# Value not found in test 8097
# Value not found in test 8149
# Value not found in test 8600
# Value not found in test 8751
# Review 9000 of 36520
#
# Value not found in test 9046
# Value not found in test 9146
# Value not found in test 9323
# Value not found in test 9424
# Value not found in test 9481
# Value not found in test 9538
# Value not found in test 9702
# Review 10000 of 36520
#
# Value not found in test 10438
# Value not found in test 10625
# Value not found in test 10663
# Value not found in test 10828
# Value not found in test 10836
# Review 11000 of 36520
#
# Value not found in test 11336
# Value not found in test 11549
# Value not found in test 11778
# Value not found in test 11785
# Value not found in test 11807
# Value not found in test 11983
# Value not found in test 11997
# Review 12000 of 36520
#
# Value not found in test 12518
# Value not found in test 12803
# Value not found in test 12809
# Review 13000 of 36520
#
# Value not found in test 13078
# Value not found in test 13240
# Value not found in test 13412
# Value not found in test 13514
# Value not found in test 13671
# Value not found in test 13882
# Review 14000 of 36520
#
# Value not found in test 14009
# Value not found in test 14034
# Value not found in test 14109
# Value not found in test 14522
# Value not found in test 14755
# Value not found in test 14981
# Review 15000 of 36520
#
# Value not found in test 15416
# Value not found in test 15646
# Review 16000 of 36520
#
# Value not found in test 16578
# Value not found in test 16592
# Review 17000 of 36520
#
# Value not found in test 17072
